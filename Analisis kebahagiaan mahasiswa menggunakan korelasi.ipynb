# %%
print('\n',input('NAMA \t\t')*3)
# Out:
# NAMA

# %% [markdown]
# ### 1. Import Library
#
# Lakukan import terhadap beberapa library berikut

# %% [markdown]
# ##### pandas dengan alias pd
# ##### pyplot dari matplotlib dengan alias plt
# ##### seaborn dengan alias sns

# %%
# CONTOH

import numpy as np

# %%
# JAWABAN
...
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Load and Reading Dataset
#
# Muat dataset yang telah kalian pilih ke dalam bentuk DataFrame, menggunakan nama variabel bebas
# ##### gunakan library pandas
# Jangan lupa untuk tampilkan dataset

# %%
# CONTOH
# data15 = pandas.read_jenisfile('namafile.jenisfile')
# data15
# print(data15)

# %%
# JAWABAN
...
df= pd.read_csv('2019.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ### 3. Drop Column
#
# Hapus sejumlah kolom menggunakan pandas, kecuali beberapa kolom berikut, yaitu; Happiness Rank, Country, GDP per Capita, Freedom, Generosity, Perception of Corruption, Social Support/Family, dan Healthy Life Expectancy. Jangan lupa untuk tampilkan dataframe yang telah diubah

# %% [markdown]
# tata cara menghapus kolom tertentu dapat dilihat di sini https://www.geeksforgeeks.org/how-to-drop-one-or-multiple-columns-in-pandas-dataframe/

# %%
# JAWABAN
...
df.drop(['Score'], axis=1)
# Out:
#      Overall rank         Country or region  GDP per capita  Social support  \
# 0               1                   Finland           1.340           1.587
# 1               2                   Denmark           1.383           1.573
# 2               3                    Norway           1.488           1.582
# 3               4                   Iceland           1.380           1.624
# 4               5               Netherlands           1.396           1.522
# ..            ...                       ...             ...             ...
# 151           152                    Rwanda           0.359           0.711
# 152           153                  Tanzania           0.476           0.885
# 153           154               Afghanistan           0.350           0.517
# 154           155  Central African Republic           0.026           0.000
# 155           156               South Sudan           0.306           0.575
#
# ...

# %% [markdown]
# ### 4. Reorder and Rename Column
#
# Lakukan penamaan ulang serta penyusunan terhadap beberapa kolom/atribut menjadi urutan baru seperti di bawah ini, dengan nama kolom spesifik sebagai berikut

# %%
# Happiness Rank
# Country
# Happiness Score
# GDP per Capita
# Social Support
# Healthy Life Expectancy
# Freedom
# Generosity
# Perceptions of Corruption

# %% [markdown]
# #### CONTOH

# %%
employee = {'EmployeeID' : [0,1,2],
     'FirstName' : ['a','b','c'],
     'LastName' : ['a','b','c'],
     'MiddleName' : ['a','b', None],
     'Contact' : ['(M) 133-245-3123', '(F)a123@gmail.com', '(F)312-533-2442 jimmy234@gmail.com']}

emp = pd.DataFrame(employee)
emp
# Out:
#    EmployeeID FirstName LastName MiddleName  \
# 0           0         a        a          a
# 1           1         b        b          b
# 2           2         c        c       None
#
#                               Contact
# 0                    (M) 133-245-3123
# 1                   (F)a123@gmail.com
# 2  (F)312-533-2442 jimmy234@gmail.com

# %% [markdown]
# #### REORDER

# %%
neworder = ['EmployeeID','FirstName','MiddleName','LastName','Contact']
contoh1 = emp.reindex(columns=neworder)
contoh1
# Out:
#    EmployeeID FirstName MiddleName LastName  \
# 0           0         a          a        a
# 1           1         b          b        b
# 2           2         c       None        c
#
#                               Contact
# 0                    (M) 133-245-3123
# 1                   (F)a123@gmail.com
# 2  (F)312-533-2442 jimmy234@gmail.com

# %%
contoh2 = emp[['EmployeeID','FirstName','MiddleName','LastName','Contact']]
contoh2
# Out:
#    EmployeeID FirstName MiddleName LastName  \
# 0           0         a          a        a
# 1           1         b          b        b
# 2           2         c       None        c
#
#                               Contact
# 0                    (M) 133-245-3123
# 1                   (F)a123@gmail.com
# 2  (F)312-533-2442 jimmy234@gmail.com

# %% [markdown]
# #### RENAME

# %%
contoh1.rename(columns={'EmployeeID':'ID Karyawan','FirstName':'Nama Depan'}, inplace=True)
contoh1
# Out:
#    ID Karyawan Nama Depan MiddleName LastName  \
# 0            0          a          a        a
# 1            1          b          b        b
# 2            2          c       None        c
#
#                               Contact
# 0                    (M) 133-245-3123
# 1                   (F)a123@gmail.com
# 2  (F)312-533-2442 jimmy234@gmail.com

# %%
contoh2.columns=['ID karyawan','Nama Depan','Nama Tengah','Nama Belakang','Kontak']
contoh2
# Out:
#    ID karyawan Nama Depan Nama Tengah Nama Belakang  \
# 0            0          a           a             a
# 1            1          b           b             b
# 2            2          c        None             c
#
#                                Kontak
# 0                    (M) 133-245-3123
# 1                   (F)a123@gmail.com
# 2  (F)312-533-2442 jimmy234@gmail.com

# %% [markdown]
# Rename dulu baru reorder, sebaliknya, atau sekaligus juga boleh

# %%
# JAWABAN
...
#rename
df.columns=['Happiness Rank','Country','Happiness Score','GDP per Capita','Social Support','Healthy Life Expectancy','Freedom','Generosity','Perceptions of Corruption']
df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP per Capita  Social Support  Healthy Life Expectancy  Freedom  \
# 0             1.340           1.587                    0.986    0.596
# ...

# %%
#reorder
df = df[['Happiness Rank','Country','Happiness Score','GDP per Capita','Social Support','Healthy Life Expectancy','Freedom','Generosity','Perceptions of Corruption']]
df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP per Capita  Social Support  Healthy Life Expectancy  Freedom  \
# 0             1.340           1.587                    0.986    0.596
# ...

# %% [markdown]
# ### 5. Checking Descriptive Statistics, Shape, and Missing Value
#
# Periksa ringkasan statistika deskriptif dengan fungsi describe() serta ukuran dari dataset dengan fungsi shape. Lalu carilah cara untuk melakukan check missing value di internet dan aplikasikan ke dalam dataset. Serta jawab serangkaian pertanyaan di bawah ini

# %%
# CONTOH
# JAWABAN SYNTAX/KODE
contoh2.shape
# Out:
# (3, 5)

# %%
# CONTOH
# 1 BAGAIMANA UKURAN DARI DATASET?
# JAWABAN SOAL
print('3 baris dan 5 kolom')
# Out:
# 3 baris dan 5 kolom

# %% [markdown]
# ##### SHAPE

# %%
# JAWABAN SYNTAX/KODE
...
df.shape
# Out:
# (156, 9)

# %%
# 1 BAGAIMANA UKURAN DARI DATASET?
# JAWABAN SOAL
...
print('156 baris and 9 kolom')
# Out:
# 156 baris and 9 kolom

# %% [markdown]
# ##### DESCRIPTIVE STATISTICS
# Jawablah beberapa pertanyaan berikut dengan menggunakan fungsi describe() dari pandas

# %%
# JAWABAN SYNTAX/KODE
...
df.describe()
# Out:
#        Happiness Rank  Happiness Score  GDP per Capita  Social Support  \
# count      156.000000       156.000000      156.000000      156.000000
# mean        78.500000         5.407096        0.905147        1.208814
# std         45.177428         1.113120        0.398389        0.299191
# min          1.000000         2.853000        0.000000        0.000000
# 25%         39.750000         4.544500        0.602750        1.055750
# 50%         78.500000         5.379500        0.960000        1.271500
# 75%        117.250000         6.184500        1.232500        1.452500
# max        156.000000         7.769000        1.684000        1.624000
#
#        Healthy Life Expectancy     Freedom  Generosity  \
# count               156.000000  156.000000  156.000000
# mean                  0.725244    0.392571    0.184846
# std                   0.242124    0.143289    0.095254
# min                   0.000000    0.000000    0.000000
# ...

# %%
# 1 BERAPA SKOR KEBAHAGIAAN TERTINGGI DAN TERENDAH BERDASARKAN DATASET?
# 2 BERAPA RATA-RATA PENDAPATAN PER KAPITA BERDASARKAN DATASET? 
# JAWABAN SOAL
...
print('no 1.', '\t','skor kebahagiaan tertinggi adalah 7.769000','\n','\t','skor terendah 2.853000')
print('no 2.', '\t','rata rata pendapat perkapita adalah 0.905147')
# Out:
# no 1. 	 skor kebahagiaan tertinggi adalah 7.769000
#  	 skor terendah 2.853000
# no 2. 	 rata rata pendapat perkapita adalah 0.905147

# %% [markdown]
# ##### MISSING VALUE
# Jawablah beberapa pertanyaan berikut dengan menggunakan syntax untuk melakukan check missing value (cari di internet)

# %%
# JAWABAN SYNTAX/KODE
...
df.isnull().sum()
# Out:
# Happiness Rank               0
# Country                      0
# Happiness Score              0
# GDP per Capita               0
# Social Support               0
# Healthy Life Expectancy      0
# Freedom                      0
# Generosity                   0
# Perceptions of Corruption    0
# dtype: int64

# %%
# 1 APAKAH ADA MISSING VALUE PADA DATASET? JIKA ADA SEBUTKAN JUMLAHNYA
# JAWABAN SOAL
...
print('no tidak ada missing value')
# Out:
# no tidak ada missing value

# %% [markdown]
# ### 6. Checking Correlation
#
# Periksa korelasi antar atribut/kolom menggunakan fungsi corr(), visualisasikan dengan heatmap dari seaborn. Lalu jawab beberapa pertanyaan di bawah ini

# %%
# CONTOH cek korelasi
# nama_dataframe.corr()


# CONTOH visualisasi heatmap
# seaborn.heatmap(nama_dataframe.corr(),
#             cmap=sns.color_palette("kode warna palet bisa dilihat di internet"),
#             annot=True)

# %%
# JAWABAN SYNTAX/KODE cek korelasi
...
df.corr()
# Out:
#                            Happiness Rank  Happiness Score  GDP per Capita  \
# Happiness Rank                   1.000000        -0.989096       -0.801947
# Happiness Score                 -0.989096         1.000000        0.793883
# GDP per Capita                  -0.801947         0.793883        1.000000
# Social Support                  -0.767465         0.777058        0.754906
# Healthy Life Expectancy         -0.787411         0.779883        0.835462
# Freedom                         -0.546606         0.566742        0.379079
# Generosity                      -0.047993         0.075824       -0.079662
# Perceptions of Corruption       -0.351959         0.385613        0.298920
#
#                            Social Support  Healthy Life Expectancy   Freedom  \
# Happiness Rank                  -0.767465                -0.787411 -0.546606
# Happiness Score                  0.777058                 0.779883  0.566742
# ...

# %%
# JAWABAN SYNTAX/KODE visualisasi heatmap
...
sns.heatmap(df.corr(),cmap=sns.color_palette("RdBu_r"),annot=True)
# Out:
# <AxesSubplot:>

# %%
# 1 APA ARTI NILAI KORELASI POSITIF DAN NEGATIF?
# 2 MENGAPA PADA DIAGONAL "\" NILAI KORELASINYA 1?
# 3 BERAPA NILAI KORELASI TERTINGGI, DAN KORELASI ANTARA ATRIBUT APAKAH ITU?
# 4 BERAPA NILAI KORELASI TERENDAH, DAN KORELASI ANTARA ATRIBUT APAKAH ITU?
# JAWABAN SOAL
...
print('no 1.', '\t','korelasi positif menunjukan pengaruh positif meningkat jika negatif turun ')
print('no 2.', '\t','jika korelasi antar variabel semakin kuat maka akan mendekati 1')
print('no 3.', '\t','korelasi tertinggi adalah -0.99 yaitu happines score dan happines rank')
print('no 4.', '\t','korelasi terendah adalah -0.03 yaitu health life expentacy dengan genosity')
# Out:
# no 1. 	 korelasi positif menunjukan pengaruh positif meningkat jika negatif turun
# no 2. 	 jika korelasi antar variabel semakin kuat maka akan mendekati 1
# no 3. 	 korelasi tertinggi adalah -0.99 yaitu happines score dan happines rank
# no 4. 	 korelasi terendah adalah -0.03 yaitu health life expentacy dengan genosity

# %% [markdown]
# ### 7. Regression Plot
#
# Dari poin ke 6, menurutmu atribut mana yang paling berpengaruh dan yang paling lemah pengaruhnya terhadap Skor Kebahagiaan? visualisasikan atribut tersebut melalui fungsi regplot dari seaborn

# %%
# CONTOH grafik regresi
# plt.figure(figsize=(10,5.5)) # ukuran visualisasi
# seaborn.set_style("whitegrid", {'axes.grid' : False}) #setting grid
# seaborn.regplot(data=namadataframe, y='nama kolom', x='nama kolom', 
#             scatter_kws={"color": "teal"}, # warna dot 
#             line_kws={"color": "darkturquoise"}) #warna line

# %%
# JAWABAN SYNTAX/KODE
...
plt.figure(figsize=(10,5.5)) # ukuran visualisasi
sns.set_style("whitegrid", {'axes.grid' : False}) #setting grid
sns.regplot(data=df, y='GDP per Capita', x='Happiness Score', scatter_kws={"color": "teal"}, # warna dot 
line_kws={"color": "darkturquoise"}) #warna line
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='GDP per Capita'>
