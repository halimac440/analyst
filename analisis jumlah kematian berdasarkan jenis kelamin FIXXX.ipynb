# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df
# Out:
#      tahun  bulan         kota_kabupaten                 kecamatan  \
# 0     2021      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1     2021      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2     2021      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3     2021      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4     2021      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# ..     ...    ...                    ...                       ...
# 529   2021      3          JAKARTA TIMUR                  CIPAYUNG
# 530   2021      3          JAKARTA TIMUR                  CIPAYUNG
# 531   2021      3          JAKARTA TIMUR                  CIPAYUNG
# 532   2021      3          JAKARTA TIMUR                  CIPAYUNG
# 533   2021      3          JAKARTA TIMUR                  CIPAYUNG
#
#              kelurahan jenis_kelamin   jumlah
# 0       PULAU PANGGANG      Laki-Laki       0
# 1         PULAU KELAPA      Laki-Laki       2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tahun           534 non-null    int64
#  1   bulan           534 non-null    int64
#  2   kota_kabupaten  534 non-null    object
#  3   kecamatan       534 non-null    object
#  4   kelurahan       534 non-null    object
#  5   jenis_kelamin   534 non-null    object
#  6   jumlah          534 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 29.3+ KB

# %%
df.groupby('kecamatan')['jumlah'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='kecamatan'>

# %%
df.groupby('jenis_kelamin ')['jumlah'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='jenis_kelamin '>

# %%
df.groupby('kota_kabupaten')['jumlah'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='kota_kabupaten'>

# %%
x = df.groupby(['kota_kabupaten'])['jumlah'].sum().to_frame().rename(columns={'jenis_kelamin':'count'}).reset_index()
x
# Out:
#           kota_kabupaten  jumlah
# 0  ADM. KEPULAUAN SERIBU      23
# 1          JAKARTA BARAT    1915
# 2          JAKARTA PUSAT    1110
# 3        JAKARTA SELATAN    2070
# 4          JAKARTA TIMUR    2728
# 5          JAKARTA UTARA    1378

# %%
abc = df.groupby(['kota_kabupaten','jenis_kelamin '])['jumlah'].sum().to_frame()
abc
# Out:
#                                       jumlah
# kota_kabupaten        jenis_kelamin
# ADM. KEPULAUAN SERIBU Laki-Laki            8
#                       Perempuan           15
# JAKARTA BARAT         Laki-Laki         1106
#                       Perempuan          809
# JAKARTA PUSAT         Laki-Laki          601
#                       Perempuan          509
# JAKARTA SELATAN       Laki-Laki         1165
#                       Perempuan          905
# JAKARTA TIMUR         Laki-Laki         1569
#                       Perempuan         1159
# JAKARTA UTARA         Laki-Laki          793
#                       Perempuan          585

# %%
abc = abc.reset_index()
abc
# Out:
#            kota_kabupaten jenis_kelamin   jumlah
# 0   ADM. KEPULAUAN SERIBU      Laki-Laki       8
# 1   ADM. KEPULAUAN SERIBU      Perempuan      15
# 2           JAKARTA BARAT      Laki-Laki    1106
# 3           JAKARTA BARAT      Perempuan     809
# 4           JAKARTA PUSAT      Laki-Laki     601
# 5           JAKARTA PUSAT      Perempuan     509
# 6         JAKARTA SELATAN      Laki-Laki    1165
# 7         JAKARTA SELATAN      Perempuan     905
# 8           JAKARTA TIMUR      Laki-Laki    1569
# 9           JAKARTA TIMUR      Perempuan    1159
# 10          JAKARTA UTARA      Laki-Laki     793
# 11          JAKARTA UTARA      Perempuan     585

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=abc['kota_kabupaten'], y=abc['jumlah'], hue=abc['jenis_kelamin '], ci=0, data=df)
# Out:
# <AxesSubplot:xlabel='kota_kabupaten', ylabel='jumlah'>

# %%
abd = df.groupby(['kecamatan','jenis_kelamin '])['jumlah'].sum().to_frame()
abd
# Out:
#                               jumlah
# kecamatan     jenis_kelamin
# CAKUNG        Laki-Laki          234
#               Perempuan          148
# CEMPAKA PUTIH Laki-Laki           57
#               Perempuan           60
# CENGKARENG    Laki-Laki          225
# ...                              ...
# TANAH ABANG   Perempuan           80
# TANJUNG PRIOK Laki-Laki          198
#               Perempuan          156
# TEBET         Laki-Laki          116
#               Perempuan          115
#
# [88 rows x 1 columns]

# %%
abd = abd.reset_index()
abd
# Out:
#         kecamatan jenis_kelamin   jumlah
# 0          CAKUNG      Laki-Laki     234
# 1          CAKUNG      Perempuan     148
# 2   CEMPAKA PUTIH      Laki-Laki      57
# 3   CEMPAKA PUTIH      Perempuan      60
# 4      CENGKARENG      Laki-Laki     225
# ..            ...            ...     ...
# 83    TANAH ABANG      Perempuan      80
# 84  TANJUNG PRIOK      Laki-Laki     198
# 85  TANJUNG PRIOK      Perempuan     156
# 86          TEBET      Laki-Laki     116
# 87          TEBET      Perempuan     115
#
# [88 rows x 3 columns]

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=abd['kecamatan'], y=abd['jumlah'], hue=abd['jenis_kelamin '], ci=0, data=df)
# Out:
# <AxesSubplot:xlabel='kecamatan', ylabel='jumlah'>

# %%
df.groupby('jenis_kelamin ')['jumlah'].sum()
# Out:
# jenis_kelamin
# Laki-Laki    5242
# Perempuan    3982
# Name: jumlah, dtype: int64

# %%
jk = df.groupby('jenis_kelamin ')['jumlah'].sum()
print(jk)
plt.title("Jenis Kelamin (kategorikal nominal)")
jk.plot.pie(autopct="%.1f%%")
# Out:
# jenis_kelamin
# Laki-Laki    5242
# Perempuan    3982
# Name: jumlah, dtype: int64
# <AxesSubplot:title={'center':'Jenis Kelamin (kategorikal nominal)'}, ylabel='jumlah'>

# %%
plt.figure(figsize=(10,7))
sns.histplot(df['jumlah'])
# Out:
# <AxesSubplot:xlabel='jumlah', ylabel='Count'>

# %%
sns.histplot(df[df['jenis_kelamin ']=='Perempuan']['jumlah'], color='darkred')
sns.histplot(df[df['jenis_kelamin ']=='Laki-Laki']['jumlah'], color='blue')
# Out:
# <AxesSubplot:xlabel='jumlah', ylabel='Count'>

# %%
df.groupby(['kota_kabupaten','jenis_kelamin '])['jumlah'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='kota_kabupaten,jenis_kelamin '>

# %%
plt.figure(figsize=(40,20))

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=df['kota_kabupaten'], y=df['jumlah'], hue=df['jenis_kelamin '], ci=0, data=df)
# Out:
# <AxesSubplot:xlabel='kota_kabupaten', ylabel='jumlah'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x=df['kota_kabupaten'], y=df['jumlah'], hue=df['jenis_kelamin '], data=df)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=df['kota_kabupaten'], y=df['jumlah'], hue=df['jenis_kelamin '], data=df)
plt.title('PERSEBARAN KEMATIAN PER-KOTA KABUPATEN BERDASARKAN JENIS KELAMIN', color='blue', size=20)
plt.show()
